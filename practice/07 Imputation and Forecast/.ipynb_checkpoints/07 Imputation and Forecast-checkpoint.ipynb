# %% [markdown]
# ## Анализ и прогнозирование временных рядов методами искусственного интеллекта

# %% [markdown]
# ### **Практическая работа 7. Восстановление пропусков и прогноз значений временного ряда.**

# %% [markdown]
# #### **7.1 Аналитичекие методы восстановления временного ряда**

# %% [markdown]
# ##### *Краткое описание*

# %% [markdown]
# В данном пункте практической работы вам предстоит познакомиться с базовыми, аналитическими методами восстановления временных рядов.
# Для выполнения данного пункта из каждой группы методов, представленных в ***табл. 7.1*** вам необходимо выбрать по одному методу восстановления ряда. При работе с первой группой, вам необходимо самостоятельно реализовать выбранный метод.
#
# **Табл. 7.1** - Группы аналитических методов восстановления.
# №|Название группы|Модели и методы|
# --|----|----|
# 1|Заполнение существующими значениями ряда|Средним, медианной, Hot-Deck|
# 2|Заполнение на основе близки значений|[Интерполяция](https://scikit-learn.org/stable/auto_examples/linear_model/plot_polynomial_interpolation.html),  [KNNi](https://scikit-learn.org/stable/modules/generated/sklearn.impute.KNNImputer.html)|
# 3|На основе матричных разложений|[CD-Rec](#Fixme:Дат ссылку), [SVD](https://pypi.org/project/fancyimpute/)|

# %% [markdown]
# ##### 7.1.1 Загрузка и подготовка данных

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

# %%
path_data = Path('datasets')/'madrid.txt'
madrid = np.loadtxt(path_data)[:,0]
print(madrid.shape)
# Out:
# (25000,)

# %%
fig, ax =  plt.subplots(figsize=(14,4),ncols=1,nrows=1)
plt.plot(madrid[:])
plt.show()

# %% [markdown]
# Самостоятельно реализуйте функцию, принимающую на вход многомерный временной ряд и возвращающий:
# 1. Все подпоследовательности временного ряда, в которых некоторые значения временного ряда были заменены nan значениями.
# 2. Индексы пропущенных значений
#
# Процент пропущенных значений должен регулироваться отдельным параметром.

# %%
def add_nan(x: np.ndarray, percent: float = 0.25):
    x = np.array(x, dtype=float).copy()

    n_total = x.size
    n_nan = int(n_total * percent)

    if n_nan <= 0:
        return x, np.array([], dtype=int)

    # случайные позиции для NaN в "плоском" виде
    perm = np.random.permutation(n_total)
    nan_idx = perm[:n_nan]

    # ставим NaN
    x_flat = x.ravel()
    x_flat[nan_idx] = np.nan
    x_missing = x_flat.reshape(x.shape)

    return x_missing, nan_idx

# %%
madrid_with_nan, index = add_nan(madrid)
fig, ax =  plt.subplots(figsize=(14,6),ncols=1,nrows=2)
ax[0].plot(madrid[:1000])
ax[1].plot(madrid_with_nan[:1000])
plt.show()

# %%
recovery = {}

# %% [markdown]
# ##### 7.1.2 Заполнение существующими значениями ряда

# %%
madrid_mean = madrid_with_nan.copy()
madrid_mean[index] = np.nanmean(madrid_mean)
recovery['mean'] = madrid_mean

# %%
fig, ax =  plt.subplots(figsize=(14,6),ncols=1,nrows=2)
ax[0].plot(madrid[:1000])
ax[1].plot(madrid_mean[:1000])
plt.show()

# %%
madrid_median = madrid_with_nan.copy()
madrid_median[index] = np.nanmedian(madrid_median)

# %%
recovery['median'] = madrid_median

# %%
#madrid_with_nan, index = add_nan(madrid)
fig, ax =  plt.subplots(figsize=(14,6),ncols=1,nrows=2)
ax[0].plot(madrid[:1000])
ax[1].plot(madrid_median[:1000])
plt.show()

# %% [markdown]
# Самостоятельно реализуйте один метод из первой группы ***табл. 7.1*** и проведите постановление данных, сохранив результаты восстановления.

# %%
# madrid_with_nan, index = add_nan(madrid)

# Hot-Deck: каждый пропуск заменяем случайно выбранным наблюдённым значением
madrid_hotdeck = madrid_with_nan.copy()

# все НЕ-пропуски — это "доноры"
observed_values = madrid_hotdeck[~np.isnan(madrid_hotdeck)]

# случайно выбираем донор для каждого пропуска
donors = np.random.choice(observed_values, size=len(index), replace=True)

# подставляем выбранные донорские значения на места пропусков
madrid_hotdeck[index] = donors

recovery['hotdeck'] = madrid_hotdeck

# визуализация
fig, ax = plt.subplots(figsize=(14, 6), ncols=1, nrows=2)
ax[0].plot(madrid[:1000])
ax[1].plot(madrid_hotdeck[:1000])
plt.show()

# %% [markdown]
# ##### 7.1.3 Заполнение на основе близких значений

# %% [markdown]
# Используя документацию одного из методов восстановления второй группы ***табл. 7.1*** и проведите восстановление данных, сохранив результаты восстановления.

# %%
from sklearn.impute import KNNImputer

# %%
from sklearn.impute import KNNImputer
import numpy as np
import matplotlib.pyplot as plt

def rolling_window(a, window, intersection=False):
    returns = []
    if intersection:  
        for i in range(0, a.shape[0] - window):
            returns.append(a[i:i + window])
    else:    
        for i in range(0, a.shape[0], window):
            returns.append(a[i:i + window])
    return np.stack(returns)

# разбиение ряда с пропусками на окна
madrid_slice = rolling_window(madrid_with_nan, 100)   # shape: (num_windows, 100)

# создаём и настраиваем KNNImputer
imputer = KNNImputer(
    n_neighbors=5,      # число соседей
    weights='distance'  # соседи взвешиваются по расстоянию
)

# восстанавливаем значения внутри окон
madrid_slice_knn = imputer.fit_transform(madrid_slice)  # та же shape

# склеиваем окна обратно в один ряд
madrid_knn = madrid_slice_knn.reshape(-1)[:madrid_with_nan.shape[0]]

# сохраняем результат восстановления
recovery['knn'] = madrid_knn

# визуализация
fig, ax = plt.subplots(figsize=(14, 6), ncols=1, nrows=2)
ax[0].plot(madrid[:1000])
ax[1].plot(madrid_knn[:1000])
plt.show()

# %% [markdown]
# ##### 7.1.4 Заполнение на матричных преобразований

# %% [markdown]
# Используя документацию одного из методов восстановления третей группы ***табл. 7.1*** и проведите восстановление данных, сохранив результаты восстановления.

# %%
# !pip install fancyimpute
# Out:
# Collecting fancyimpute
#   Downloading fancyimpute-0.7.0.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting knnimpute>=0.1.0 (from fancyimpute)
#   Downloading knnimpute-0.1.0.tar.gz (8.3 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: scikit-learn>=0.24.2 in d:\anaconda\lib\site-packages (from fancyimpute) (1.4.2)
# Collecting cvxpy (from fancyimpute)
#   Downloading cvxpy-1.7.3-cp312-cp312-win_amd64.whl.metadata (9.7 kB)
# Collecting cvxopt (from fancyimpute)
#   Downloading cvxopt-1.3.2-cp312-cp312-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: pytest in d:\anaconda\lib\site-packages (from fancyimpute) (7.4.4)
# Collecting nose (from fancyimpute)
#   Downloading nose-1.3.7-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from knnimpute>=0.1.0->fancyimpute) (1.16.0)
# Requirement already satisfied: numpy>=1.10 in d:\anaconda\lib\site-packages (from knnimpute>=0.1.0->fancyimpute) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in d:\anaconda\lib\site-packages (from scikit-learn>=0.24.2->fancyimpute) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\anaconda\lib\site-packages (from scikit-learn>=0.24.2->fancyimpute) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda\lib\site-packages (from scikit-learn>=0.24.2->fancyimpute) (2.2.0)
# Collecting osqp>=1.0.0 (from cvxpy->fancyimpute)
#   Downloading osqp-1.0.5-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting clarabel>=0.5.0 (from cvxpy->fancyimpute)
#   Downloading clarabel-0.11.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting scs>=3.2.4.post1 (from cvxpy->fancyimpute)
#   Downloading scs-3.2.9-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: iniconfig in d:\anaconda\lib\site-packages (from pytest->fancyimpute) (1.1.1)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from pytest->fancyimpute) (23.2)
# Requirement already satisfied: pluggy<2.0,>=0.12 in d:\anaconda\lib\site-packages (from pytest->fancyimpute) (1.0.0)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from pytest->fancyimpute) (0.4.6)
# Requirement already satisfied: cffi in d:\anaconda\lib\site-packages (from clarabel>=0.5.0->cvxpy->fancyimpute) (1.16.0)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from osqp>=1.0.0->cvxpy->fancyimpute) (3.1.4)
# Requirement already satisfied: setuptools in d:\anaconda\lib\site-packages (from osqp>=1.0.0->cvxpy->fancyimpute) (69.5.1)
# Requirement already satisfied: pycparser in d:\anaconda\lib\site-packages (from cffi->clarabel>=0.5.0->cvxpy->fancyimpute) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from jinja2->osqp>=1.0.0->cvxpy->fancyimpute) (2.1.3)
# Downloading cvxopt-1.3.2-cp312-cp312-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.8 MB 388.9 kB/s eta 0:00:33
#    ---------------------------------------- 0.1/12.8 MB 491.5 kB/s eta 0:00:26
#    ---------------------------------------- 0.1/12.8 MB 491.5 kB/s eta 0:00:26
#    ---------------------------------------- 0.1/12.8 MB 491.5 kB/s eta 0:00:26
#    ---------------------------------------- 0.2/12.8 MB 573.4 kB/s eta 0:00:23
#     --------------------------------------- 0.2/12.8 MB 655.1 kB/s eta 0:00:20
#     --------------------------------------- 0.2/12.8 MB 654.9 kB/s eta 0:00:20
#     --------------------------------------- 0.3/12.8 MB 707.1 kB/s eta 0:00:18
#    - -------------------------------------- 0.3/12.8 MB 805.1 kB/s eta 0:00:16
#    - -------------------------------------- 0.4/12.8 MB 794.9 kB/s eta 0:00:16
#    - -------------------------------------- 0.4/12.8 MB 794.9 kB/s eta 0:00:16
#    - -------------------------------------- 0.4/12.8 MB 794.9 kB/s eta 0:00:16
#    - -------------------------------------- 0.6/12.8 MB 913.7 kB/s eta 0:00:14
#    - -------------------------------------- 0.6/12.8 MB 926.6 kB/s eta 0:00:14
#    -- ------------------------------------- 0.6/12.8 MB 922.8 kB/s eta 0:00:14
#    -- ------------------------------------- 0.7/12.8 MB 911.5 kB/s eta 0:00:14
#    -- ------------------------------------- 0.7/12.8 MB 899.4 kB/s eta 0:00:14
# %%
from fancyimpute import IterativeSVD

# %%
from sklearn.metrics import mean_squared_error

# %%
# 1. Разбиваем ряд с NaN на окна
window_size = 100
madrid_slice = rolling_window(madrid_with_nan, window_size)  # shape: (num_windows, window_size)

# 2. Создаём и запускаем IterativeSVD
svd_imputer = IterativeSVD(
    rank=10,                  # ранг низкорангового приближения
    convergence_threshold=1e-4,
    max_iters=100,
    verbose=False
)

madrid_slice_svd = svd_imputer.fit_transform(madrid_slice)    # та же shape, уже без NaN

# 3. Склеиваем окна обратно в один ряд
madrid_svd = madrid_slice_svd.reshape(-1)[:madrid_with_nan.shape[0]]

# 4. Сохраняем результат восстановления
recovery['svd'] = madrid_svd

# 5. Считаем ошибку только на восстановленных точках
mse_svd = mean_squared_error(madrid[index], madrid_svd[index])
print("MSE IterativeSVD:", mse_svd)

# 6. Визуализация
fig, ax = plt.subplots(figsize=(14, 6), ncols=1, nrows=2)
ax[0].plot(madrid[:1000])
ax[0].set_title("Оригинальный ряд (первые 1000 точек)")
ax[1].plot(madrid_svd[:1000])
ax[1].set_title("Восстановление IterativeSVD (первые 1000 точек)")
plt.tight_layout()
plt.show()
# Out:
# MSE IterativeSVD: 28305.391146620826

# %% [markdown]
# ##### 7.1.5 Сравнение результатов восстановления.

# %% [markdown]
# Для каждой группы методов постройте методов основные метрики оценки качества постановления.
# На основе метрик отберите лучшие методы постановления метрик и выберите лучшую группу методов.
# Для лучших методов из каждой группы постройте графики сравнения реальных и восстановленных данных. Объясните результаты и сделайте вывод.

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
import matplotlib.pyplot as plt

def compute_metrics(true, pred, idx):
    true_vals = true[idx]
    pred_vals = pred[idx]

    mae  = mean_absolute_error(true_vals, pred_vals)
    mse  = mean_squared_error(true_vals, pred_vals)
    rmse = np.sqrt(mse)

    return {
        'MAE': mae,
        'MSE': mse,
        'RMSE': rmse,
    }

metrics = {}

for name, rec in recovery.items():
    metrics[name] = compute_metrics(madrid, rec, index)

metrics
# Out:
# {'mean': {'MAE': 336.45651747840003,
#   'MSE': 154791.54363732482,
#   'RMSE': 393.4355647845335},
#  'median': {'MAE': 336.24272, 'MSE': 154974.82288, 'RMSE': 393.66841742766206},
#  'hotdeck': {'MAE': 450.98992, 'MSE': 313228.28304, 'RMSE': 559.6680114496451},
#  'knn': {'MAE': 135.181850410453,
#   'MSE': 38215.185320316814,
#   'RMSE': 195.48704642588677},
#  'svd': {'MAE': 122.27145577121517,
#   'MSE': 28305.391146620826,
#   'RMSE': 168.24206116967548}}

# %%
import pandas as pd

df_metrics = pd.DataFrame(metrics).T
df_metrics
# Out:
#                 MAE            MSE        RMSE
# mean     336.456517  154791.543637  393.435565
# median   336.242720  154974.822880  393.668417
# hotdeck  450.989920  313228.283040  559.668011
# knn      135.181850   38215.185320  195.487046
# svd      122.271456   28305.391147  168.242061

# %%
group1 = df_metrics.loc[['mean', 'median', 'hotdeck']]
best_group1 = group1['RMSE'].idxmin()
best_group1
# Out:
# 'mean'

# %%
best_group2 = 'knn'
best_group3 = 'svd'

# %%
winners = df_metrics.loc[[best_group1, best_group2, best_group3]]
winners
# Out:
#              MAE            MSE        RMSE
# mean  336.456517  154791.543637  393.435565
# knn   135.181850   38215.185320  195.487046
# svd   122.271456   28305.391147  168.242061

# %%
best_global = winners['RMSE'].idxmin()
best_global
# Out:
# 'svd'

# %%
plt.figure(figsize=(16, 8))

plt.plot(madrid[:1000], label='Original', linewidth=2)

plt.plot(recovery[best_group1][:1000], label=f'Best Group 1: {best_group1}')
plt.plot(recovery[best_group2][:1000], label='Best Group 2: knn')
plt.plot(recovery[best_group3][:1000], label='Best Group 3: svd')

plt.legend()
plt.title("Сравнение восстановления для победителей групп")
plt.show()

# %%
plt.figure(figsize=(14,6))
plt.plot(madrid[:1000], label='Original')
plt.plot(recovery[best_global][:1000], label=f'Best Global: {best_global}')
plt.title("Лучший метод восстановления")
plt.legend()
plt.show()

# %% [markdown]
# *Вывод*: По результатам расчета метрик видно, что методы первой группы (mean, median, hot-deck) показывают наихудшее качество восстановления: их ошибки MAE и RMSE примерно в 2–3 раза выше, чем у более продвинутых подходов. Особенно слабым оказался hot-deck, который дал наибольшую ошибку из всех методов. Во второй группе метод KNNImputer существенно улучшает качество: ошибки снижаются почти в четыре раза по сравнению с простыми методами, что показывает эффективность использования близких по структуре окон. Наилучшие результаты демонстрирует метод IterativeSVD из третьей группы. Он обеспечивает минимальные значения MAE, MSE и RMSE, что означает наиболее точное восстановление пропущенных значений.

# %% [markdown]
# #### **7.2 Нейросетевые методы востановления временного ряда**

# %% [markdown]
# ##### *Краткое описание*

# %% [markdown]
# В данном пункте практической работы вам предстоит познакомиться с некоторыми нейросетевыми методами восстановления временных рядов.
# Для выполнения данного пункта вам предстоит самостоятельно реализовать структуру нейросетевой, модели основанной на GRU нейронах и сравнить ее с другими нейросетевыми методами восстановления При сравнении с 3 группой из **табл.7. 2** вам необходимо выбрать **один** метод восстановления. Основные блоки обработки данных будут реализованы с использованием Pytorch. Вам не запрещается использовать для реализации Keras.
#
# **табл. 7.2** - Нейросетевые методы восстановления.
# №|Название группы|Модели и методы|
# --|-------------|----|
# 1|Линейные нейроны|[Pytorch](https://pytorch.org/docs/stable/generated/torch.nn.Linear.html)|
#  2eкрркуретные нейронны|[Pytorch](https://pytorch.org/docs/stable/generated/torch.nn.GRU.html)|
# 3|Сложные структуры|[SAITS, BRITS, M-RNN](https://github.com/WenjieDu/PyPOTS)|

# %%
recovery_nn = {}

# %% [markdown]
# ##### 7.2.1 Загрузка и подготовка данных

# %%
path_data = Path('Dataset')/'madrid.txt'
madrid = np.loadtxt(path_data)[:,:]
print(madrid.shape)
# Out:
# (25000, 10)

# %%
madrid_with_nan, index = add_nan(madrid, 0.25)
# Out:
# (25000, 10) (25000, 10)

# %%
madrid_with_nan.shape
# Out:
# (25000, 10)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
madrid_normal_with_nan = scaler.fit_transform(madrid_with_nan)
rolling_madrid = rolling_window(madrid_normal_with_nan, 100, True)
train, test = train_test_split(rolling_madrid,shuffle=False, test_size=0.33)

# %% [markdown]
# ##### 7.2.2 Базовая модель восстановления данных, построенная на нескольких слоях линейных нейронов.

# %% [markdown]
# Вам необходимо будет самостоятельно реализовать:
# 1. инициализацию nan значений какими либо другими значениями.
# 2. замер времени полного обучения и тестирования модели.

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader

# %%
class LinearModel(nn.Module):
    def __init__(self, size_subsequent: int,dim = 1, nums_layers = 3, size_layers = 250):
        super().__init__()  
        
        self.size_subsequent = size_subsequent
        self.nums_layers = nums_layers*dim
        self.dim = dim
        self.size_layers = size_layers
        
        self.start_layers = nn.Sequential(nn.Flatten(),
                                          nn.Linear(size_subsequent*dim, self.size_layers),
                                          nn.LeakyReLU())
        self.model = nn.ModuleList([
                                        (nn.Sequential(
                                                nn.Linear(self.size_layers, self.size_layers), nn.LeakyReLU()
                                            ) 
                                        )
                                    for x in torch.arange(nums_layers)])
        self.model = nn.Sequential(*self.model)
        
        self.output = nn.Sequential(nn.Linear(self.size_layers,size_subsequent*dim),nn.Tanh())
        
    def forward(self, x):
        x = self.start_layers(x)
        
        x=self.model(x)
        x=self.output(x)
        return x.reshape(x.shape[0],self.size_subsequent,self.dim)

# %%
model = LinearModel(size_subsequent=train.shape[1],dim=train.shape[2])
optimizer = torch.optim.Adam(model.parameters(),lr=1.0e-3)
loss_func = nn.MSELoss()
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
batch_size = 64
percent = 0.25

train_loader = DataLoader(train,batch_size=batch_size,shuffle=True)
valid_loader = DataLoader(test,batch_size=batch_size,shuffle=True)

print(train.shape,test.shape)
epochs = 100
# Out:
# (16683, 100, 10) (8217, 100, 10)

# %%
model
# Out:
# LinearModel(
#   (start_layers): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=1000, out_features=250, bias=True)
#     (2): LeakyReLU(negative_slope=0.01)
#   )
#   (model): Sequential(
#     (0): Sequential(
#       (0): Linear(in_features=250, out_features=250, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=250, out_features=250, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=250, out_features=250, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (output): Sequential(
#     (0): Linear(in_features=250, out_features=1000, bias=True)
#     (1): Tanh()
#   )
# )

# %%
import time
times_model = {}

# %%
model=model.to(device)
train_history = []
valid_history = []

start = time.time()
for epoch in np.arange(epochs):
    train_loss =0
    valid_loss =0

    for i, x in enumerate(train_loader):
        if x.shape[0] == batch_size:
            optimizer.zero_grad()
            x = x.to(device).to(torch.float32)
            test_index = np.isnan(x.cpu().numpy())
            X = x.clone()
            X, nan = add_nan(X,percent)
            ###вставте инициализацию нулями nan значений
            recovery = model(X)
            loss = loss_func(recovery[(nan)&(~test_index)],x[(nan)&(~test_index)])
            train_loss += loss.detach().cpu().item()
            loss.backward()
            optimizer.step()
    train_loss/=(i+1)
    print('valid')
    with torch.no_grad():
        for i, x in enumerate(valid_loader):
            if x.shape[0] == batch_size:
                x = x.to(device).to(torch.float32)
                test_index = np.isnan(x.cpu().numpy())
                X = x.clone()
                X, nan = add_nan(X,percent)
                X[torch.isnan(X)]=0.0
                recovery = model(X)
                loss = loss_func(recovery[(nan)&(~test_index)],x[(nan)&(~test_index)])
                valid_loss += loss.detach().cpu().item()
    valid_loss/=(i+1)
    train_history.append(train_loss)
    valid_history.append(valid_loss)
    print(f'epoch:{epoch+1} train:{train_loss}, valid:{valid_loss}')
end = time.time()
# Out:
# valid
# epoch:1 train:0.01611318807492311, valid:0.008655089661190215
# valid
# epoch:2 train:0.008517843498081197, valid:0.007346930891968483
# valid
# epoch:3 train:0.006750307350965409, valid:0.005705035605662784
# valid
# epoch:4 train:0.005377719610558387, valid:0.00529541350655662
# valid
# epoch:5 train:0.00477882488755602, valid:0.004763821233785891
# valid
# epoch:6 train:0.004289024376570893, valid:0.004202899887666915
# valid
# epoch:7 train:0.0039321740025875665, valid:0.004013050436006151
# valid
# epoch:8 train:0.0036666128058271963, valid:0.0037690944312674594
# valid
# epoch:9 train:0.0034416405880160032, valid:0.003823137316896125
# valid
# epoch:10 train:0.003276596601403022, valid:0.0035195500398588968
# valid
# epoch:11 train:0.003150434458942306, valid:0.0034511806948702463
# valid
# epoch:12 train:0.0029987307690026886, valid:0.0032823553900848063
# valid
# epoch:13 train:0.0028882348157065808, valid:0.003274920024699712
# valid
# epoch:14 train:0.0027794978675928497, valid:0.003105788782253399
# valid
# epoch:15 train:0.0027015648757275266, valid:0.0030703773314147724
# valid
# epoch:16 train:0.0026367620245635625, valid:0.0031763602232257296
# valid
# epoch:17 train:0.0025296572602971305, valid:0.0031728562989178323
# valid
# epoch:18 train:0.0024616294861610592, valid:0.003011124123739757
# valid
# epoch:19 train:0.0023929229241678083, valid:0.002927063042009177
# valid
# epoch:20 train:0.00231821627456024, valid:0.0029023327962170507
# valid
# epoch:21 train:0.002274086234566552, valid:0.002786416282458592
# valid
# epoch:22 train:0.0022361610348825252, valid:0.002888481370931448
# valid
# epoch:23 train:0.0022021270012732783, valid:0.002815403780618379
# valid
# epoch:24 train:0.002143079050998578, valid:0.002705470079469473
# valid
# epoch:25 train:0.0021202066356594534, valid:0.0026748708878867617
# valid
# epoch:26 train:0.00208929592343868, valid:0.0027445373323912075
# valid
# epoch:27 train:0.0020406381097725695, valid:0.0025731114302436973
# valid
# epoch:28 train:0.0020232637028363303, valid:0.0026593519999219698
# valid
# epoch:29 train:0.00200007199506022, valid:0.002618740448121761
# valid
# epoch:30 train:0.0019790624260324343, valid:0.0026206359512699665
# valid
# epoch:31 train:0.0019465691920269952, valid:0.00277166778958121
# valid
# epoch:32 train:0.0019288339471030566, valid:0.0025648910321237504
# valid
# epoch:33 train:0.0019164195162033612, valid:0.002620326985005838
# valid
# epoch:34 train:0.0019133925996363962, valid:0.002624255709725526
# valid
# epoch:35 train:0.0018721568198353624, valid:0.00252500664291167
# valid
# epoch:36 train:0.0018564670148637444, valid:0.002543616718648709
# valid
# epoch:37 train:0.0018390178634924278, valid:0.002551076150419869
# valid
# epoch:38 train:0.001830183592682055, valid:0.0024628344464816096
# valid
# epoch:39 train:0.0018252118948268994, valid:0.002450905252941126
# valid
# epoch:40 train:0.0018082574407759183, valid:0.0024816967788794937
# valid
# epoch:41 train:0.0018005462687184241, valid:0.002491287134457813
# valid
# epoch:42 train:0.0017848802365583879, valid:0.002472598408890325
# valid
# epoch:43 train:0.001761103160875596, valid:0.002492173906964387
# valid
# epoch:44 train:0.0017551690147354685, valid:0.002442993701962653
# valid
# epoch:45 train:0.001752420894130779, valid:0.0024555512620930294
# valid
# epoch:46 train:0.0017433006073779987, valid:0.0025249623762111564
# valid
# epoch:47 train:0.0017250541221150606, valid:0.0024290299367939316
# valid
# epoch:48 train:0.0017041031122243325, valid:0.0024166124324177126
# valid
# epoch:49 train:0.001701876556793392, valid:0.0024037742102879654
# valid
# epoch:50 train:0.001701170761027584, valid:0.002421309456749018
# valid
# epoch:51 train:0.0016862449461016163, valid:0.0023899741954523926
# valid
# epoch:52 train:0.00167091966025046, valid:0.002420448622298102
# valid
# epoch:53 train:0.0016625157273749169, valid:0.0023986610056933506
# valid
# epoch:54 train:0.0016641784539638922, valid:0.002372209912223756
# valid
# epoch:55 train:0.0016404761245003205, valid:0.0024140560674632706
# valid
# epoch:56 train:0.0016459622264258077, valid:0.0024192789118274933
# valid
# epoch:57 train:0.0016425850197237513, valid:0.0024016278763409962
# valid
# epoch:58 train:0.0016317200419667865, valid:0.00240081848121833
# valid
# epoch:59 train:0.0016288933744725426, valid:0.002473031031689787
# valid
# epoch:60 train:0.0016239173598837293, valid:0.0023943981617804647
# valid
# epoch:61 train:0.00161477359782519, valid:0.0024161713807879723
# valid
# epoch:62 train:0.0016017417843592749, valid:0.0024023338892432146
# valid
# epoch:63 train:0.0016014393801725973, valid:0.0023739781328152086
# valid
# epoch:64 train:0.0015945173171081249, valid:0.002359225566304007
# valid
# epoch:65 train:0.0015938214786436367, valid:0.0024614086204980926
# valid
# epoch:66 train:0.0015834217710006568, valid:0.002280473918473536
# valid
# epoch:67 train:0.0015843049828248577, valid:0.002406317908533437
# valid
# epoch:68 train:0.0015624937689702573, valid:0.0023743572442741817
# valid
# epoch:69 train:0.001566559005835561, valid:0.002343592033613213
# valid
# epoch:70 train:0.0015853794694831774, valid:0.002391825316387207
# valid
# epoch:71 train:0.0015510534782897524, valid:0.002283533017129399
# valid
# epoch:72 train:0.001567453004587513, valid:0.0023716655595935592
# valid
# epoch:73 train:0.0015506564230940009, valid:0.0023502631387276244
# valid
# epoch:74 train:0.0015528151458593163, valid:0.0023690852780588146
# valid
# epoch:75 train:0.0015464320545124025, valid:0.002323884524173977
# valid
# epoch:76 train:0.0015427037369695373, valid:0.002377941854326993
# valid
# epoch:77 train:0.0015210413027883032, valid:0.002362244026085665
# valid
# epoch:78 train:0.001538305361826558, valid:0.0023157993952433267
# valid
# epoch:79 train:0.001539942932893233, valid:0.0023582461290061474
# valid
# epoch:80 train:0.0015178344371261153, valid:0.0024525481637191864
# valid
# epoch:81 train:0.0015360462988666134, valid:0.0023570736895438082
# valid
# epoch:82 train:0.0015232094025624723, valid:0.0024645479645060246
# valid
# epoch:83 train:0.0015056476124537346, valid:0.002490723350395759
# valid
# epoch:84 train:0.001520676032989732, valid:0.0022720365582914776
# valid
# epoch:85 train:0.0015055425438344821, valid:0.002327356897222326
# valid
# epoch:86 train:0.0015259497848935282, valid:0.002309003115682177
# valid
# epoch:87 train:0.001513569241111306, valid:0.002249715416583904
# valid
# epoch:88 train:0.0014966426228112417, valid:0.002341525058817956
# valid
# epoch:89 train:0.0015236698095490479, valid:0.002389169276453728
# valid
# epoch:90 train:0.0015041904530213198, valid:0.0023461318026159624
# valid
# epoch:91 train:0.001487747812019197, valid:0.0024061909761250943
# valid
# epoch:92 train:0.001488208570035881, valid:0.002297882237940911
# valid
# epoch:93 train:0.0014799904632221523, valid:0.0023087658486220727
# valid
# epoch:94 train:0.0014808360363224742, valid:0.002333140271434257
# valid
# epoch:95 train:0.001482182382195617, valid:0.002319958748642442
# valid
# epoch:96 train:0.0014787307254420558, valid:0.0023816482402211014
# valid
# epoch:97 train:0.0014848220108569354, valid:0.002299283194362886
# valid
# epoch:98 train:0.0014762896460113455, valid:0.0023536873022960716
# valid
# epoch:99 train:0.0014712136623296187, valid:0.0022962766053342774
# valid
# epoch:100 train:0.0014752831285055799, valid:0.0023975617887611075

# %%
times_model['linear']=end-start

# %%
plt.plot(train_history,label='train')
plt.plot(valid_history,label='valid')
plt.legend()
plt.show()

# %%
test_rolling_madrid = rolling_window(madrid_normal_with_nan, 100, False)
#test = []
with torch.no_grad():
    for idx, batch in enumerate(test_rolling_madrid):
        batch = torch.Tensor(batch).to(device)
        nan = torch.isnan(batch)
        batch[nan]=0.0
        rec = model(batch[None,:])[0].cpu().numpy()
        nan = nan.cpu().numpy()
        test_rolling_madrid[idx][nan]=rec[nan]

# %%
test_madrid_normal = np.vstack(test_rolling_madrid)
test_linear = scaler.inverse_transform(test_madrid_normal)

# %%
recovery_nn['linear'] = test_linear

# %%
fig, ax =  plt.subplots(figsize=(14,3),ncols=1,nrows=1)

plt.plot(madrid[:1000,0])
plt.plot(test_linear[:1000,0],alpha=0.6)
print(mean_squared_error(madrid[index].reshape(1,-1),test_linear[index].reshape(1,-1)))
# Out:
# 19223.47670004051

# %% [markdown]
# ##### 7.2.3 Реккурентная модель востановлениях данных

# %%
class EncoderGRU(nn.Module):
    def __init__(self, size_subsequent: int, dim = 1, latten_size = 100, hidden_size=100):
        super().__init__()
        self.size_subsequent=size_subsequent
        self.dim = dim
        self.hidden_size = hidden_size
        self.gru = nn.GRU(input_size=dim,
                          hidden_size=self.hidden_size)
        
        self.latten = nn.Linear(hidden_size*size_subsequent,latten_size)
        self.leaky = nn.LeakyReLU()
        self.fl = nn.Flatten()
    def forward(self, x):
        x, _ = self.gru(x)
        x = self.leaky(x)
        #print(x.shape)
        x = self.fl(x)
        x = self.latten(x)
        return self.leaky(x)

# %%
class DecoderGRU(nn.Module):
    def __init__(self, size_subsequent: int, dim = 1, latten_size = 100, hidden_size=100):
        super().__init__()
        self.size_subsequent=size_subsequent
        self.dim = dim
        self.hidden_size = hidden_size
        self.latten_size=latten_size
        self.gru = nn.GRU(input_size=self.hidden_size,
                          hidden_size=dim)
        self.latten = nn.Linear(latten_size,hidden_size*size_subsequent)
        self.leaky = nn.LeakyReLU()
    
    def forward(self, x):
        x = self.latten(x)
        x = x.view(-1, self.size_subsequent, self.latten_size)
        x = self.leaky(x)
        x, _ = self.gru(x)
        return self.leaky(x)

# %%
class TimeAE(nn.Module):
    def __init__(self, size_subsequent: int, dim = 1, latten_size = 100, hidden_size=100):
        super().__init__()
        self.encoder = EncoderGRU(size_subsequent=size_subsequent,
                                 dim=dim,
                                 latten_size=latten_size,
                                 hidden_size=hidden_size) 
        self.decoder = DecoderGRU(size_subsequent=size_subsequent,
                                 dim=dim,
                                 latten_size=latten_size,
                                 hidden_size=hidden_size) 
    def forward(self, x):
        x=self.encoder(x)
        x = self.decoder(x)
        return x

# %%
model = TimeAE(size_subsequent=train.shape[1],dim=train.shape[2])
optimizer = torch.optim.Adam(model.parameters(),lr=1.0e-3)
loss_func = nn.MSELoss()
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
batch_size = 64
percent = 0.25

train_loader = DataLoader(train,batch_size=batch_size,shuffle=True)
valid_loader = DataLoader(test,batch_size=batch_size,shuffle=True)


epochs = 100

# %%
model
# Out:
# TimeAE(
#   (encoder): EncoderGRU(
#     (gru): GRU(10, 100)
#     (latten): Linear(in_features=10000, out_features=100, bias=True)
#     (leaky): LeakyReLU(negative_slope=0.01)
#     (fl): Flatten(start_dim=1, end_dim=-1)
#   )
#   (decoder): DecoderGRU(
#     (gru): GRU(100, 10)
#     (latten): Linear(in_features=100, out_features=10000, bias=True)
#     (leaky): LeakyReLU(negative_slope=0.01)
#   )
# )

# %%
model=model.to(device)
train_history = []
valid_history = []
start = time.time()
for epoch in np.arange(epochs):
    train_loss =0
    valid_loss =0

    for i, x in enumerate(train_loader):
        if x.shape[0]==batch_size:
            optimizer.zero_grad()
            x = x.to(device).to(torch.float32)
            test_index = np.isnan(x.cpu().numpy())
            X = x.clone()
            X, nan = add_nan(X,percent)
            #
            
            recovery = model(X)
            loss = loss_func(recovery[(nan)&(~test_index)],x[(nan)&(~test_index)])
            train_loss += loss.detach().cpu().item()
            loss.backward()
            optimizer.step()
    train_loss/=(i+1)
    with torch.no_grad():
        for i, x in enumerate(valid_loader):
            if x.shape[0]==batch_size:
                x = x.to(device).to(torch.float32)
                test_index = np.isnan(x.cpu().numpy())
                X = x.clone()
                X, nan = add_nan(X,percent)
                # 
                
                recovery = model(X)
                loss = loss_func(recovery[(nan)&(~test_index)],x[(nan)&(~test_index)])
                valid_loss += loss.detach().cpu().item()
    valid_loss/=(i+1)
    train_history.append(train_loss)
    valid_history.append(valid_loss)
    print(f'epoch:{epoch+1} train:{train_loss}, valid:{valid_loss}')
end = time.time()
# Out:
# epoch:1 train:0.005667857565271215, valid:0.0048371934866200585
# epoch:2 train:0.00420799586293912, valid:0.004097167624507186
# epoch:3 train:0.0035405969621891947, valid:0.003608167110112055
# epoch:4 train:0.003133067681893021, valid:0.0032865865636154895
# epoch:5 train:0.002844720459775107, valid:0.0030663977774192195
# epoch:6 train:0.0026280734780819025, valid:0.0028908427194656097
# epoch:7 train:0.0024395643169652687, valid:0.002762273224720428
# epoch:8 train:0.002310831576114756, valid:0.002648445248762651
# epoch:9 train:0.0021598582576168165, valid:0.002507162047550082
# epoch:10 train:0.0020520448929119955, valid:0.002424571598165257
# epoch:11 train:0.0019568192395221055, valid:0.002385350184284093
# epoch:12 train:0.0018743742489295216, valid:0.0022636219126338413
# epoch:13 train:0.0018025992480124493, valid:0.0022381309459577926
# epoch:14 train:0.001751357673888605, valid:0.002197221281591716
# epoch:15 train:0.0016929136809511146, valid:0.002117336496653021
# epoch:16 train:0.001646642735534815, valid:0.0020511770411575027
# epoch:17 train:0.0015876086636614126, valid:0.0020145903514741464
# epoch:18 train:0.0015538076391101055, valid:0.0020007810450714918
# epoch:19 train:0.0015159790882291236, valid:0.0019655735385351518
# epoch:20 train:0.0014870170717059823, valid:0.001934996402692483
# epoch:21 train:0.0014629344945645024, valid:0.0019042570533794026
# epoch:22 train:0.0014351392017634607, valid:0.0019146379619446952
# epoch:23 train:0.0014176183604096488, valid:0.00186485232868369
# epoch:24 train:0.0013913782532023573, valid:0.0018490065600318733
# epoch:25 train:0.001368902882354127, valid:0.0018317194731342931
# epoch:26 train:0.0013466642222142425, valid:0.0018006087508225857
# epoch:27 train:0.0013333770385818462, valid:0.0018230855163518889
# epoch:28 train:0.0013135319024367236, valid:0.0017810144277592731
# epoch:29 train:0.0012870389206327813, valid:0.001767278980109985
# epoch:30 train:0.001275184848417182, valid:0.001747813082097979
# epoch:31 train:0.0012678609615891202, valid:0.0017714784354289142
# epoch:32 train:0.001254355611183263, valid:0.0017424027007722923
# epoch:33 train:0.001239294847259405, valid:0.001729748811024104
# epoch:34 train:0.0012265690325820012, valid:0.0017241859472854886
# epoch:35 train:0.0012191778340580306, valid:0.001713714836699556
# epoch:36 train:0.0012053452589160182, valid:0.0017178725927721621
# epoch:37 train:0.0011988017896290197, valid:0.001680705125999543
# epoch:38 train:0.0011879894445325566, valid:0.0016757650779155914
# epoch:39 train:0.0011760737680940679, valid:0.0016668402506832697
# epoch:40 train:0.0011655644119371057, valid:0.001705556066504629
# epoch:41 train:0.0011569426918644958, valid:0.0016807086193616422
# epoch:42 train:0.0011532863872339841, valid:0.0016620952442880403
# epoch:43 train:0.001138761623314728, valid:0.0016782453099568916
# epoch:44 train:0.0011324187719719877, valid:0.0016481467322338112
# epoch:45 train:0.0011230841322741347, valid:0.0016307296734952995
# epoch:46 train:0.0011178437121733451, valid:0.0016453813295811415
# epoch:47 train:0.0011071918703530026, valid:0.001630168029128812
# epoch:48 train:0.0011074356264184975, valid:0.0016455832478958507
# epoch:49 train:0.001095724349861101, valid:0.0016421674644256862
# epoch:50 train:0.001090637645264909, valid:0.001621462509411481
# epoch:51 train:0.0010831661832829316, valid:0.0016229615091930987
# epoch:52 train:0.0010759062954435175, valid:0.0016214504031204554
# epoch:53 train:0.00107320239727289, valid:0.0016026566357373497
# epoch:54 train:0.0010698996725138918, valid:0.001610060810840638
# epoch:55 train:0.0010578712855262317, valid:0.0016104646582993888
# epoch:56 train:0.0010549888327910468, valid:0.0016027104313478106
# epoch:57 train:0.001048463754225665, valid:0.001601135928559211
# epoch:58 train:0.0010420855795304465, valid:0.0015953107603442992
# epoch:59 train:0.0010435933067010166, valid:0.001613899264953915
# epoch:60 train:0.0010388768481008595, valid:0.0015808041243590126
# epoch:61 train:0.00102800214988754, valid:0.0015765774955381025
# epoch:62 train:0.0010322307995199386, valid:0.0015746725780903831
# epoch:63 train:0.00102360860977172, valid:0.0015656563350497637
# epoch:64 train:0.001015204734434784, valid:0.001567359682526295
# epoch:65 train:0.0010119174663744638, valid:0.001578217195419147
# epoch:66 train:0.0010134025320314385, valid:0.0015751365815874102
# epoch:67 train:0.0010050949071876533, valid:0.0015724392719711213
# epoch:68 train:0.0010020310131447583, valid:0.0015724693513439261
# epoch:69 train:0.0009972511168919018, valid:0.0015470232144936687
# epoch:70 train:0.0009961685409298402, valid:0.0015706477231930854
# epoch:71 train:0.0009919003112031097, valid:0.0015649314231578578
# epoch:72 train:0.0009809744785632582, valid:0.0015448957100481719
# epoch:73 train:0.0009847193623186443, valid:0.0015517317639418351
# epoch:74 train:0.000983167965575282, valid:0.0015461397611774331
# epoch:75 train:0.000974410233378653, valid:0.0015504505979835755
# epoch:76 train:0.0009709812102614548, valid:0.0015462397456948841
# epoch:77 train:0.0009671033277993458, valid:0.0015469701309118043
# epoch:78 train:0.0009643632840093981, valid:0.0015320026535945114
# epoch:79 train:0.0009653237617085778, valid:0.0015370333774823897
# epoch:80 train:0.000962460886596049, valid:0.0015515535808161133
# epoch:81 train:0.0009600292046918351, valid:0.0015489712895377893
# epoch:82 train:0.0009581661507508706, valid:0.0015390334170773741
# epoch:83 train:0.0009499252140450637, valid:0.0015420413823336247
# epoch:84 train:0.0009542327009362679, valid:0.0015376487551906773
# epoch:85 train:0.0009447208728812549, valid:0.0015372007457149584
# epoch:86 train:0.0009408305246129603, valid:0.00155602987447768
# epoch:87 train:0.0009401118056313403, valid:0.001542696769009958
# epoch:88 train:0.0009336544433162615, valid:0.0015212695507780295
# epoch:89 train:0.0009381620253978647, valid:0.0015523678022111918
# epoch:90 train:0.0009321501559731318, valid:0.0015297242568430398
# epoch:91 train:0.0009320442347566087, valid:0.0015073981020570725
# epoch:92 train:0.0009276046271799881, valid:0.00152922456528154
# epoch:93 train:0.0009312005816170253, valid:0.0015185398849218276
# epoch:94 train:0.0009277866534635396, valid:0.0015211227095447654
# epoch:95 train:0.0009263127110452459, valid:0.001516291147004091
# epoch:96 train:0.0009154978380413633, valid:0.0015143666483187514
# epoch:97 train:0.0009176039094126772, valid:0.001517397214391435
# epoch:98 train:0.000916958295238843, valid:0.0015192465620230912
# epoch:99 train:0.0009132948738854678, valid:0.0015283837461439792
# epoch:100 train:0.0009158381296168314, valid:0.001519506459680292

# %%
plt.plot(train_history,label='train')
plt.plot(valid_history,label='valid')
plt.legend()
plt.show()

# %%
times_model['ae']=end-start

# %%
test_rolling_madrid = rolling_window(madrid_normal_with_nan, 100, False)
#test = []
with torch.no_grad():
    for idx, batch in enumerate(test_rolling_madrid):
        batch = torch.Tensor(batch).to(device)
        nan = torch.isnan(batch)
        #
        
        rec = model(batch[None,:])[0].cpu().numpy()
        nan = nan.cpu().numpy()
        test_rolling_madrid[idx][nan]=rec[nan]

# %%
test_madrid_normal = np.vstack(test_rolling_madrid)
test_ae = scaler.inverse_transform(test_madrid_normal)

# %%
recovery_nn['test_ae'] = test_ae

# %%
fig, ax =  plt.subplots(figsize=(14,3),ncols=1,nrows=1)

plt.plot(madrid[:1000,0])
plt.plot(test_ae[:1000,0],alpha=0.6)
print(mean_squared_error(madrid[index].reshape(1,-1),test_ae[index].reshape(1,-1)))
# Out:
# 7815.347353696892

# %% [markdown]
# ##### 7.2.4 Сложные модели нейросетевого восстановления данных

# %% [markdown]
# Вам необходимо выбрать одну модель из 3 группы таблицы 7.2 и используя документацию произвести восстановления того же ряда. Произведите замер времени.

# %%
# !pip install pypots==0.0.9

# %%
from pypots.imputation import SAITS

# %%
model= SAITS(n_features=madrid.shape[1],
             n_steps=100,
             device=device,
             d_k=64,
             d_v=64,
             d_model=128,
             d_inner=128,
             n_head=4,
             n_layers=2,
             dropout=0.05,
             epochs=100)
# Out:
# Model initialized successfully. Number of the trainable parameters: 667608

# %%
start = time.time()
model.fit(train,test)
end = time.time()
times_model['saits']=end-start
# Out:
# epoch 0: training loss 0.1332, validating loss 0.0487
# epoch 1: training loss 0.0748, validating loss 0.0418

# %%
test_rolling_madrid = rolling_window(madrid_normal_with_nan, 100, False)
test_rolling_madrid = model.impute(test_rolling_madrid)

# %%
test_madrid_normal = np.vstack(test_rolling_madrid)
test_saits = scaler.inverse_transform(test_madrid_normal)

# %%
recovery_nn['saits'] = test_saits

# %%
fig, ax =  plt.subplots(figsize=(14,3),ncols=1,nrows=1)

plt.plot(madrid[:1000,0])
plt.plot(test_saits[:1000,0],alpha=0.6)
print(mean_squared_error(madrid[index].reshape(1,-1),test_saits[index].reshape(1,-1)))
# Out:
# 4653.035675034267

# %% [markdown]
# ##### 7.2.5 Сравнения результатов.
# Также, как и в пункте 7.1.5 постройте графики сравнения моделей. Дополнительно постройте графики сравнения времени. Сделайте выводы

# %% [markdown]
# #### **7.3 Прогноз временного ряда**

# %% [markdown]
# ##### *Краткое описание*

# %% [markdown]
# Используя модель и [ARIMA](реализация) произвидите прогноз ряда на следующие колличество точек: 1, 5, 10.
# Сравните результаты. Постройте графики прогноза и точности прогноза.
